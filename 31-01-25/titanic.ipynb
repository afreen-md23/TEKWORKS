# %%
import pandas as pd
data=pd.read_csv("test.csv")
data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
pclass=data["Pclass"]
pclass
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
numerical_cols=data.select_dtypes(include=['number'])
y=numerical_cols['Age']
x=numerical_cols.drop(columns='Age' , axis=1)
x.corr().round(2)
# Out:
#              PassengerId  Pclass  SibSp  Parch  Fare
# PassengerId         1.00   -0.03   0.00   0.04  0.01
# Pclass             -0.03    1.00   0.00   0.02 -0.58
# SibSp               0.00    0.00   1.00   0.31  0.17
# Parch               0.04    0.02   0.31   1.00  0.23
# Fare                0.01   -0.58   0.17   0.23  1.00

# %%
import seaborn as sns
sns.heatmap(x.corr().round(2) ,annot=True ,cmap="coolwarm")
# Out:
# <Axes: >

# %%
import pandas as pd 
from sklearn.preprocessing import LabelEncoder

data={'Difficulty' : ['Easy' , 'Medium','Hard', 'Medium','Easy'],
     'Test Score' : [50,60,70,80,90]}

df=pd.DataFrame(data)

encoder =LabelEncoder()

df['Difficulty_encoded']=encoder.fit_transform(df['Difficulty'])
print(df)

correlation =df['Difficulty_encoded'].corr(df['Test Score'])
print("Correlation :" ,correlation)
# Out:
#   Difficulty  Test Score  Difficulty_encoded
# 0       Easy          50                   0
# 1     Medium          60                   2
# 2       Hard          70                   1
# 3     Medium          80                   2
# 4       Easy          90                   0
# Correlation : 0.0

# %%
import pandas as pd


data = {'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red']}
df = pd.DataFrame(data)


df_encoded = pd.get_dummies(df, columns=['Color'])


df_encoded['Test Score'] = [80, 85, 90, 75, 88]  # Example test scores

print(df_encoded)

# Calculating the correlation
correlation = df_encoded['Color_Red'].corr(df_encoded['Test Score'])
print("Correlation with Red:", correlation)
# Out:
#    Color_Blue  Color_Green  Color_Red  Test Score
# 0       False        False       True          80
# 1        True        False      False          85
# 2       False         True      False          90
# 3        True        False      False          75
# 4       False        False       True          88
# Correlation with Red: 0.05978812755559512

# %%
import pandas as pd
 
# Sample data

data = {'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red'],

        'Test Score': [50, 60, 70, 80, 90]}
 
# Create a DataFrame

df = pd.DataFrame(data)
 
# Apply One-Hot Encoding

df_encoded = pd.get_dummies(df, columns=['Color'])
 

print(df_encoded)
 
# Calculate the correlation

correlation = df_encoded['Color_Red'].corr(df_encoded['Test Score'])

print("Correlation with Red:", correlation)
# Out:
#    Test Score  Color_Blue  Color_Green  Color_Red
# 0          50       False        False       True
# 1          60        True        False      False
# 2          70       False         True      False
# 3          80        True        False      False
# 4          90       False        False       True
# Correlation with Red: -1.2819751242557094e-17
