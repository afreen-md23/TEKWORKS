# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd
data=pd.read_csv("Sample_inventors.csv")

# %%
data
# Out:
#       Dealer_ID         Dealer_Name     Location  Product_ID  \
# 0           101  Alpha Distributors     New York        1002
# 1           102       Beta Supplies  Los Angeles        1004
# 2           103       Gamma Traders      Chicago        1001
# 3           104   Delta Wholesalers      Houston        1006
# 4           105   Epsilon Retailers        Miami        1001
# ...         ...                 ...          ...         ...
# 1045        106    Zeta Enterprises      Seattle        1002
# 1046        110       Kappa Dealers       Boston        1003
# 1047        102       Beta Supplies          NaN        1006
# 1048        106    Zeta Enterprises      Seattle        1001
# 1049        105   Epsilon Retailers          NaN        1007
#
#              Product_Name Stock_Level  Daily_Consumption  Reorder_Threshold  \
# 0     Mechanical Keyboard         577               30.0                173
# 1     Portable Hard Drive         421                6.0                200
# ...

# %%
data.isnull().sum()
# Out:
# Dealer_ID             0
# Dealer_Name          20
# Location             20
# Product_ID            0
# Product_Name         20
# Stock_Level           0
# Daily_Consumption    10
# Reorder_Threshold     0
# Last_Updated          0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data=data.drop_duplicates()
data
# Out:
#      Dealer_ID         Dealer_Name       Location  Product_ID  \
# 0          101  Alpha Distributors       New York        1002
# 1          102       Beta Supplies    Los Angeles        1004
# 2          103       Gamma Traders        Chicago        1001
# 3          104   Delta Wholesalers        Houston        1006
# 4          105   Epsilon Retailers          Miami        1001
# ..         ...                 ...            ...         ...
# 995        106    Zeta Enterprises        Seattle        1007
# 996        107       Eta Solutions         Dallas        1005
# 997        108       Theta Imports  San Francisco        1001
# 998        109   Iota Distributors         Denver        1004
# 999        110       Kappa Dealers         Boston        1010
#
#             Product_Name Stock_Level  Daily_Consumption  Reorder_Threshold  \
# 0    Mechanical Keyboard         577               30.0                173
# ...

# %%
#Loading the dataset 
df=pd.read_csv("inventory_data_cleaned.csv")
df
# Out:
#       Dealer_ID Product_ID        Date  Quantity  Consumption     Location
# 0          D000       P000  2022-01-01      62.0          8.0      Chicago
# 1          D000       P000  2022-01-02      70.0          9.0      Chicago
# 2          D000       P000  2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000  2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000  2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...         ...       ...          ...          ...
# 18171      D001       P012  2022-02-19      71.0         15.0  Los Angeles
# 18172      D003       P014  2022-01-26      47.0         12.0  Los Angeles
# 18173      D001       P013  2022-02-14      89.0          8.0      Chicago
# 18174      D004       P017  2022-03-24      29.0          6.0     New York
# 18175      D005       P003  2022-03-01      33.0          7.0      Chicago
#
# [18176 rows x 6 columns]

# %%
#checking the duplicates in the data
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18171     True
# 18172     True
# 18173     True
# 18174     True
# 18175     True
# Length: 18176, dtype: bool

# %%
#checking missing values from the data
df.isnull().sum()
# Out:
# Dealer_ID      0
# Product_ID     0
# Date           0
# Quantity       0
# Consumption    0
# Location       0
# dtype: int64

# %%
#Removing the rows which are duplicates
df=df.drop_duplicates()
df
# Out:
#       Dealer_ID Product_ID        Date  Quantity  Consumption     Location
# 0          D000       P000  2022-01-01      62.0          8.0      Chicago
# 1          D000       P000  2022-01-02      70.0          9.0      Chicago
# 2          D000       P000  2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000  2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000  2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...         ...       ...          ...          ...
# 18052      D001       P015  2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010  2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014  2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013  2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002  2022-03-12      42.0          6.0      Chicago
#
# [17827 rows x 6 columns]

# %%
df.isnull()
# Out:
#        Dealer_ID  Product_ID   Date  Quantity  Consumption  Location
# 0          False       False  False     False        False     False
# 1          False       False  False     False        False     False
# 2          False       False  False     False        False     False
# 3          False       False  False     False        False     False
# 4          False       False  False     False        False     False
# ...          ...         ...    ...       ...          ...       ...
# 18052      False       False  False     False        False     False
# 18080      False       False  False     False        False     False
# 18144      False       False  False     False        False     False
# 18153      False       False  False     False        False     False
# 18159      False       False  False     False        False     False
#
# [17827 rows x 6 columns]

# %%
#checking the infromation about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 0 to 18159
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dealer_ID    17827 non-null  object
#  1   Product_ID   17827 non-null  object
#  2   Date         17827 non-null  object
#  3   Quantity     17827 non-null  float64
#  4   Consumption  17827 non-null  float64
#  5   Location     17827 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 974.9+ KB

# %%
# It describes the about the data
df.describe()
# Out:
#                                 Date      Quantity   Consumption         Year  \
# count                          17433  17827.000000  17827.000000      17827.0
# mean   2022-02-14 03:23:41.786267136     54.428956     12.038818  1977.311157
# min              2022-01-01 00:00:00     10.000000      5.000000          0.0
# 25%              2022-01-23 00:00:00     32.000000      8.000000       2022.0
# 50%              2022-02-14 00:00:00     54.000000     12.000000       2022.0
# 75%              2022-03-08 00:00:00     77.000000     16.000000       2022.0
# max              2022-03-30 00:00:00     99.000000     19.000000       2022.0
# std                              NaN     25.872482      4.318566   297.268741
#
#           Month        Day
# count   17827.0    17827.0
# mean   1.955236  14.845403
# min         0.0        0.0
# 25%         1.0        7.0
# 50%         2.0       15.0
# 75%         3.0       22.0
# max         3.0       30.0
# std    0.867798    8.69253

# %%
# Filling missing values in numerical columns with mean
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns  

for col in numerical_cols:
    # Calculate the mean
    mean_value = df[col].mean() 
    # Fill missing values with mean
    df[col] = df[col].fillna(mean_value)

# %%
df
# Out:
#       Dealer_ID Product_ID        Date  Quantity  Consumption     Location
# 0          D000       P000  2022-01-01      62.0          8.0      Chicago
# 1          D000       P000  2022-01-02      70.0          9.0      Chicago
# 2          D000       P000  2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000  2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000  2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...         ...       ...          ...          ...
# 18052      D001       P015  2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010  2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014  2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013  2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002  2022-03-12      42.0          6.0      Chicago
#
# [17827 rows x 6 columns]

# %%
# Filling missing values in categorical columns with mode
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    # Get the mode (most frequent value) of the column
    mode_value = df[col].mode()[0]
    # Fill missing values with mode
    df[col] = df[col].fillna(mode_value)

print(df)
# Out:
#       Dealer_ID Product_ID        Date  Quantity  Consumption     Location
# 0          D000       P000  2022-01-01      62.0          8.0      Chicago
# 1          D000       P000  2022-01-02      70.0          9.0      Chicago
# 2          D000       P000  2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000  2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000  2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...         ...       ...          ...          ...
# 18052      D001       P015  2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010  2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014  2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013  2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002  2022-03-12      42.0          6.0      Chicago
#
# [17827 rows x 6 columns]

# %%
df.isnull()
# Out:
#        Dealer_ID  Product_ID   Date  Quantity  Consumption  Location
# 0          False       False  False     False        False     False
# 1          False       False  False     False        False     False
# 2          False       False  False     False        False     False
# 3          False       False  False     False        False     False
# 4          False       False  False     False        False     False
# ...          ...         ...    ...       ...          ...       ...
# 18052      False       False  False     False        False     False
# 18080      False       False  False     False        False     False
# 18144      False       False  False     False        False     False
# 18153      False       False  False     False        False     False
# 18159      False       False  False     False        False     False
#
# [17827 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline 
import warnings 
warnings.filterwarnings('ignore')

# %%
df
# Out:
#       Dealer_ID Product_ID        Date  Quantity  Consumption     Location
# 0          D000       P000  2022-01-01      62.0          8.0      Chicago
# 1          D000       P000  2022-01-02      70.0          9.0      Chicago
# 2          D000       P000  2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000  2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000  2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...         ...       ...          ...          ...
# 18052      D001       P015  2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010  2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014  2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013  2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002  2022-03-12      42.0          6.0      Chicago
#
# [17827 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 0 to 18159
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dealer_ID    17827 non-null  object
#  1   Product_ID   17827 non-null  object
#  2   Date         17827 non-null  object
#  3   Quantity     17827 non-null  float64
#  4   Consumption  17827 non-null  float64
#  5   Location     17827 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 974.9+ KB

# %%
#Converting the Date object to the datetime
df['Date']=pd.to_datetime(df['Date'],errors="coerce")
df.dtypes
# Out:
# Dealer_ID              object
# Product_ID             object
# Date           datetime64[ns]
# Quantity              float64
# Consumption           float64
# Location               object
# dtype: object

# %%
# Split the Date column into Year, Month, and Day
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# Show the updated DataFrame with Year, Month, and Day
print(df[['Date', 'Year', 'Month', 'Day']].head())
# Out:
#         Date    Year  Month  Day
# 0 2022-01-01  2022.0    1.0  1.0
# 1 2022-01-02  2022.0    1.0  2.0
# 2 2022-01-03  2022.0    1.0  3.0
# 3 2022-01-04  2022.0    1.0  4.0
# 4 2022-01-05  2022.0    1.0  5.0

# %%
df
# Out:
#       Dealer_ID Product_ID       Date  Quantity  Consumption     Location  \
# 0          D000       P000 2022-01-01      62.0          8.0      Chicago
# 1          D000       P000 2022-01-02      70.0          9.0      Chicago
# 2          D000       P000 2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000 2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000 2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...        ...       ...          ...          ...
# 18052      D001       P015 2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010 2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014 2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013 2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002 2022-03-12      42.0          6.0      Chicago
#
#          Year  Month   Day
# 0      2022.0    1.0   1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17827 entries, 0 to 18159
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dealer_ID    17827 non-null  object
#  1   Product_ID   17827 non-null  object
#  2   Date         17433 non-null  datetime64[ns]
#  3   Quantity     17827 non-null  float64
#  4   Consumption  17827 non-null  float64
#  5   Location     17827 non-null  object
#  6   Year         17433 non-null  float64
#  7   Month        17433 non-null  float64
#  8   Day          17433 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 1.4+ MB

# %%
# Fill NaN values with 0 (or another placeholder) before converting to int
df[['Year', 'Month', 'Day']] = df[['Year', 'Month', 'Day']].fillna(0).astype(int)

# Show the updated DataFrame
print(df[['Year', 'Month', 'Day']].head())
# Out:
#    Year  Month  Day
# 0  2022      1    1
# 1  2022      1    2
# 2  2022      1    3
# 3  2022      1    4
# 4  2022      1    5

# %%
# Convert columns to nullable integers (Int64) to preserve NaN values
df[['Year', 'Month', 'Day']] = df[['Year', 'Month', 'Day']].astype('Int64')

# Show the updated DataFrame
print(df[['Year', 'Month', 'Day']].head())
# Out:
#    Year  Month  Day
# 0  2022      1    1
# 1  2022      1    2
# 2  2022      1    3
# 3  2022      1    4
# 4  2022      1    5

# %%
df
# Out:
#       Dealer_ID Product_ID       Date  Quantity  Consumption     Location  \
# 0          D000       P000 2022-01-01      62.0          8.0      Chicago
# 1          D000       P000 2022-01-02      70.0          9.0      Chicago
# 2          D000       P000 2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000 2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000 2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...        ...       ...          ...          ...
# 18052      D001       P015 2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010 2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014 2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013 2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002 2022-03-12      42.0          6.0      Chicago
#
#        Year  Month  Day
# 0      2022      1    1
# 1      2022      1    2
# ...

# %%
print(df.shape)
# Out:
# (17827, 9)

# %%
print(df.describe())
# Out:
#                                 Date      Quantity   Consumption         Year  \
# count                          17433  17827.000000  17827.000000      17827.0
# mean   2022-02-14 03:23:41.786267136     54.428956     12.038818  1977.311157
# min              2022-01-01 00:00:00     10.000000      5.000000          0.0
# 25%              2022-01-23 00:00:00     32.000000      8.000000       2022.0
# 50%              2022-02-14 00:00:00     54.000000     12.000000       2022.0
# 75%              2022-03-08 00:00:00     77.000000     16.000000       2022.0
# max              2022-03-30 00:00:00     99.000000     19.000000       2022.0
# std                              NaN     25.872482      4.318566   297.268741
#
#           Month        Day
# count   17827.0    17827.0
# mean   1.955236  14.845403
# min         0.0        0.0
# 25%         1.0        7.0
# 50%         2.0       15.0
# 75%         3.0       22.0
# max         3.0       30.0
# std    0.867798    8.69253

# %%
# Histogram for Quantity Distribution
# A histogram allows us to see the distribution of the 'Quantity' data across different bins.
# It helps to identify patterns like the spread of values, skewness, or outliers.
df['Quantity'].hist(bins=50)  # 'bins=50' divides the data into 50 intervals
plt.title('Quantity Distribution')  # Adding a title to the histogram
plt.show()  # Display the plot

# Box Plot for Consumption
# A box plot is useful for visualizing the summary statistics of 'Consumption' data,
# including the median, quartiles, and any potential outliers.
sns.boxplot(x=df['Consumption'])  # 'x' axis represents the 'Consumption' column
plt.title('Daily Consumption Box Plot')  # Adding a title to the box plot
plt.show()  # Display the plot

# %%
df
# Out:
#       Dealer_ID Product_ID       Date  Quantity  Consumption     Location  \
# 0          D000       P000 2022-01-01      62.0          8.0      Chicago
# 1          D000       P000 2022-01-02      70.0          9.0      Chicago
# 2          D000       P000 2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000 2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000 2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...        ...       ...          ...          ...
# 18052      D001       P015 2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010 2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014 2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013 2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002 2022-03-12      42.0          6.0      Chicago
#
#        Year  Month  Day
# 0      2022      1    1
# 1      2022      1    2
# ...

# %%
# Get unique locations in the 'Location' column
unique_locations = df['Location'].unique()

# Print the unique locations
print(unique_locations)
# Out:
# ['Chicago' 'Los Angeles' 'New York']

# %%
# Convert columns to nullable integers (Int64) to preserve NaN values
df[['Year', 'Month', 'Day']] = df[['Year', 'Month', 'Day']].astype('Int64')

# Show the updated DataFrame
print(df[['Year', 'Month', 'Day']].head())
# Out:
#    Year  Month  Day
# 0  2022      1    1
# 1  2022      1    2
# 2  2022      1    3
# 3  2022      1    4
# 4  2022      1    5

# %%
print(df)
# Out:
#       Dealer_ID Product_ID       Date  Quantity  Consumption     Location  \
# 0          D000       P000 2022-01-01      62.0          8.0      Chicago
# 1          D000       P000 2022-01-02      70.0          9.0      Chicago
# 2          D000       P000 2022-01-03      12.0         17.0  Los Angeles
# 3          D000       P000 2022-01-04      74.0         13.0  Los Angeles
# 4          D000       P000 2022-01-05      57.0         10.0  Los Angeles
# ...         ...        ...        ...       ...          ...          ...
# 18052      D001       P015 2022-03-05      97.0         15.0  Los Angeles
# 18080      D001       P010 2022-01-27      26.0         18.0      Chicago
# 18144      D001       P014 2022-01-14      30.0          5.0      Chicago
# 18153      D001       P013 2022-01-26      48.0         15.0      Chicago
# 18159      D000       P002 2022-03-12      42.0          6.0      Chicago
#
#        Year  Month  Day
# 0      2022      1    1
# 1      2022      1    2
# ...

# %%
# Plotting 'Consumption' over time (with 'Date' on x-axis)
plt.plot(df['Date'], df['Consumption'], color='blue')  # Line plot with 'Date' on the x-axis and 'Consumption' on the y-axis

# Adding title and labels for clarity
plt.title('Consumption Over Time')  # Title of the plot to indicate what the plot is showing
plt.xlabel('Date')  # Label for the x-axis representing time (Date)
plt.ylabel('Consumption')  # Label for the y-axis representing the amount of consumption

# Adding gridlines for better readability of values
plt.grid(True)  # This adds gridlines to the plot, making it easier to read the values

# Show the plot
plt.show()  # Displays the plot

# %%
# Grouping the data by 'Month' and summing the 'Consumption' for each month
monthly_consumption = df.groupby('Month')['Consumption'].sum()  # This groups the data by 'Month' and sums 'Consumption'

# Plotting the result as a bar plot
monthly_consumption.plot(kind='bar', color='skyblue')  # Creates a bar plot with 'skyblue' color

# Adding the title and axis labels for clarity
plt.title('Monthly Consumption')  # Title of the plot
plt.xlabel('Month')  # Label for the x-axis
plt.ylabel('Total Consumption')  # Label for the y-axis

# Setting x-ticks to be horizontal for better readability
plt.xticks(rotation=0)  # Keeps the month labels horizontal on the x-axis

# Display the plot
plt.show()  # Displays the plot

# %%
plt.figure(figsize=(8, 5))
# Scatter plot showing the relationship between 'Quantity' and 'Consumption'
plt.scatter(df['Quantity'], df['Consumption'], alpha=0.1, color='green')

# Title of the plot
plt.title('Consumption vs Quantity')

# Labeling the x-axis (Quantity)
plt.xlabel('Quantity')

# Labeling the y-axis (Consumption)
plt.ylabel('Consumption')

# Adding a grid for better visibility of data points
plt.grid(True)

# Display the plot
plt.show()

# %%
plt.figure(figsize=(8, 5))
location_consumption = df.groupby('Location')['Consumption'].sum()
location_consumption.plot(kind='bar', color='orange')
plt.title('Consumption by Location')
plt.xlabel('Location')
plt.ylabel('Total Consumption')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
monthly_location_consumption = df.groupby(['Month', 'Location'])['Consumption'].sum().unstack()
monthly_location_consumption.plot(kind='line', marker='o')
plt.title('Monthly Consumption by Location')
plt.xlabel('Month')
plt.ylabel('Total Consumption')
plt.legend(title='Location')
plt.show()

# %%
product_consumption = df.groupby('Product_ID')['Consumption'].sum()
product_consumption.sort_values(ascending=False).plot(kind='bar', color='purple')
plt.title('Total Consumption by Product')
plt.xlabel('Product ID')
plt.ylabel('Total Consumption')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.hist(df['Consumption'], bins=20, color='teal', edgecolor='black')
plt.title('Distribution of Consumption')
plt.xlabel('Consumption')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
monthly_location_consumption = df.groupby(['Month', 'Location'])['Consumption'].sum().unstack()
plt.figure(figsize=(10, 6))
sns.heatmap(monthly_location_consumption, annot=True, fmt='.1f', cmap='YlGnBu', cbar=True)
plt.title('Heatmap of Consumption by Month and Location')
plt.xlabel('Location')
plt.ylabel('Month')
plt.show()

# %%
dealer_consumption = df.groupby('Dealer_ID')['Consumption'].sum()
dealer_consumption.sort_values(ascending=False).plot(kind='bar', color='red')
plt.title('Total Consumption by Dealer')
plt.xlabel('Dealer ID')
plt.ylabel('Total Consumption')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
sns.boxplot(x='Location', y='Consumption', data=df)
plt.title('Consumption Spread by Location')
plt.xlabel('Location')
plt.ylabel('Consumption')
plt.xticks(rotation=45)
plt.show()

# %%
## Boxplots to visualize outliers

# Creating a subplot with a 2x3 grid of plots
plt.figure(figsize=(18, 12))

# Boxplot for 'Quantity'
plt.subplot(2, 3, 3)  # This places the boxplot in the 3rd position of a 2x3 grid
sns.boxplot(data=df_eda, x='Quantity', color='blue')  # Creates a boxplot for the 'Quantity' column, with blue color
plt.title('Boxplot of Quantity')  # Title of the boxplot

# Boxplot for 'Consumption'
plt.subplot(2, 3, 4)  # This places the second boxplot in the 4th position of a 2x3 grid
sns.boxplot(data=df_eda, x='Consumption', color='blue')  # Creates a boxplot for the 'Consumption' column, with blue color
plt.title('Boxplot of Consumption')  # Title of the boxplot

# Show all plots in the figure
plt.show()

# %% [markdown]
# Both columns  quantity and consumption have the outliers

# %%
# Function to remove outliers using the Interquartile Range (IQR) method
def remove_outliers_iqr(df, columns):
    # Loop through each column specified for outlier removal
    for col in columns:
        # Calculate the first quartile (25th percentile) for the column
        Q1 = df[col].quantile(0.25)  # First quartile (25%)
        
        # Calculate the third quartile (75th percentile) for the column
        Q3 = df[col].quantile(0.75)  # Third quartile (75%)
        
        # Calculate the Interquartile Range (IQR)
        IQR = Q3 - Q1  # Interquartile range (difference between Q3 and Q1)
        
        # Determine the lower and upper bounds to detect outliers
        lower_bound = Q1 - 1.5 * IQR  # Any value below this is considered an outlier
        upper_bound = Q3 + 1.5 * IQR  # Any value above this is considered an outlier
        
        # Filter the DataFrame to remove the rows with outliers
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    
    # Return the DataFrame after removing outliers
    return df

# Select the columns for outlier removal (adjust as needed)
columns_to_filter = ["Quantity", "Consumption"]  # Columns for which outliers will be removed

# Apply the outlier removal function to the DataFrame
df = remove_outliers_iqr(df, columns_to_filter)  # Filter out outliers from the DataFrame

# %%
df_eda = df  # Assuming df is the original dataframe

# Setting up the plotting area: figsize makes the plot large for better visualization
plt.figure(figsize=(18, 12))

# **Distribution of numerical columns**

# Plot 1: Distribution of Quantity
plt.subplot(2, 3, 1)  # Creating a subplot in a 2x3 grid, 1st position
sns.histplot(df_eda['Quantity'], kde=True, color='blue')  # Creating a histogram with a KDE (Kernel Density Estimation)
plt.title('Distribution of Quantity')  # Title for the plot
# Purpose: This histogram with KDE shows how the 'Quantity' values are distributed.
# The histogram divides the data into bins to visualize the frequency of different ranges of values,
# while the KDE curve helps understand the overall distribution shape (smoothing the histogram).
# It helps to identify whether the data is skewed, has multiple peaks, or follows a normal distribution.

# Plot 2: Distribution of Consumption
plt.subplot(2, 3, 2)  # Creating a subplot in the 2nd position of the grid
sns.histplot(df_eda['Consumption'], kde=True, color='blue')  # Similar to the first plot, but for 'Consumption'
plt.title('Distribution of Consumption')  # Title for the plot
# Purpose: This plot does the same for the 'Consumption' variable.
# Like the 'Quantity' distribution, this histogram allows us to visualize the frequency of different consumption values.
# The KDE helps to see if the consumption is distributed in a bell-shaped curve or skewed.

# Show the plots after they've been created
plt.tight_layout()  # Adjust the spacing between subplots for a clean layout
plt.show()

# %%
#Finding the unique values of Dealer Product IDs and location
print("Categories in 'Dealer_ID' variable:     ",end=" " )
print(df['Dealer_ID'].unique())

print("Categories in 'Product_ID' variable:  ",end=" ")
print(df['Product_ID'].unique())

print("Categories in'Location' variable:",end=" " )
print(df['Location'].unique())
# Out:
# Categories in 'Dealer_ID' variable:      ['D000' 'D001' 'D002' 'D003' 'D004' 'D005' 'D006' 'D007' 'D008' 'D009']
# Categories in 'Product_ID' variable:   ['P000' 'P001' 'P002' 'P003' 'P004' 'P005' 'P006' 'P007' 'P008' 'P009'
#  'P010' 'P011' 'P012' 'P013' 'P014' 'P015' 'P016' 'P017' 'P018' 'P019']
# Categories in'Location' variable: ['Chicago' 'Los Angeles' 'New York']

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 6 numerical features : ['Date', 'Quantity', 'Consumption', 'Year', 'Month', 'Day']
#
# We have 3 categorical features : ['Dealer_ID', 'Product_ID', 'Location']

# %%
## Adding column requirement based on Quantity and Consumption
low_threshold = df["Consumption"].quantile(0.33)
high_threshold = df["Consumption"].quantile(0.66)

# %%
# Create a new categorical target column
def categorize_consumption(value):
    if value <= low_threshold:
        return "Low"
    elif value <= high_threshold:
        return "Medium"
    else:
        return "High"

df["Consumption_Level"] = df["Consumption"].apply(categorize_consumption)

df['Quantity_consumption_ratios'] = df['Quantity']/df['Consumption']

# %%
df.head()
# Out:
#   Dealer_ID Product_ID       Date  Quantity  Consumption     Location  Year  \
# 0      D000       P000 2022-01-01      62.0          8.0      Chicago  2022
# 1      D000       P000 2022-01-02      70.0          9.0      Chicago  2022
# 2      D000       P000 2022-01-03      12.0         17.0  Los Angeles  2022
# 3      D000       P000 2022-01-04      74.0         13.0  Los Angeles  2022
# 4      D000       P000 2022-01-05      57.0         10.0  Los Angeles  2022
#
#    Month  Day Consumption_Level  Quantity_consumption_ratios
# 0      1    1               Low                     7.750000
# 1      1    2               Low                     7.777778
# 2      1    3              High                     0.705882
# 3      1    4            Medium                     5.692308
# 4      1    5               Low                     5.700000

# %%
## Histogram & KDE

# Creating two subplots side by side for comparing the distribution of 'Quantity' 
# and its relationship with the 'Consumption_Level' feature in one view.
fig, axs = plt.subplots(1, 2, figsize=(15, 7))  # Create a figure with 1 row and 2 columns

# Plot 1: Distribution of 'Quantity' with histogram and KDE
plt.subplot(121)  # Left subplot in the 1x2 grid
sns.histplot(data=df, x='Quantity', bins=30, kde=True, color='g')  # Histogram with KDE curve for 'Quantity'
plt.title('Distribution of Quantity')  # Title for the first subplot

# Plot 2: Distribution of 'Quantity' with KDE and hue based on 'Consumption_Level'
plt.subplot(122)  # Right subplot in the 1x2 grid
sns.histplot(data=df, x='Quantity', kde=True, hue='Consumption_Level')  # KDE with hue for 'Consumption_Level'
plt.title('Quantity vs Consumption Level')  # Title for the second subplot

plt.show()  # Display the plots

# %%
# Create subplots: 1 row, 2 columns
fig, axs = plt.subplots(1, 2, figsize=(15, 7))

# Plot 1: Distribution of 'Consumption' with bins and KDE
plt.subplot(121)
sns.histplot(data=df, x='Consumption', bins=30, kde=True, color='g')
plt.title('Distribution of Consumption with Bins')

# Purpose:
# - Purpose: Shows the distribution of 'Consumption' values with both histograms (binned) and a KDE (Kernel Density Estimate) curve.
# - Why this is useful:This plot helps visualize how consumption values are spread across different ranges (e.g., low to high).
# - The KDE curve smooths the distribution, providing a clearer sense of the shape of the data, while the histogram shows the frequency in each bin.
# - Helps in identifying any skewness or concentration in the consumption data, making it easier to understand consumption trends.

# Plot 2: Distribution of 'Consumption' with KDE and colored by 'Consumption_Level'
plt.subplot(122)
sns.histplot(data=df, x='Consumption', kde=True, hue='Consumption_Level')
plt.title('Consumption Distribution by Consumption Level')

# Purpose:
# - Purpose: Visualizes the distribution of 'Consumption' values, but also segments the data based on 'Consumption_Level'.
# - Why this is useful:
#   - The `hue='Consumption_Level'` parameter colors the data according to different consumption levels, allowing you to distinguish different groups (e.g., low, medium, high consumption).
#   - Helps in comparing how the different consumption levels impact the overall distribution and identify patterns.
#   - The KDE curve provides a smooth representation of the consumption distribution for each level, making it easier to observe differences in consumption behavior.

# Show all plots
plt.show()

# %%
plt.subplots(1,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='Quantity',kde=True,hue='Consumption_Level')

plt.show()

# %%
plt.subplots(1,figsize=(25,6))
plt.subplot(142)
sns.histplot(data=df[df.Location=='Chicago'],x='Quantity',kde=True,hue='Consumption_Level')
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
plt.subplots(1,figsize=(25,6))
plt.subplot(143)
sns.histplot(data=df[df.Location=='Los Angeles'],x='Quantity',kde=True,hue='Consumption_Level')
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
plt.subplots(1,figsize=(25,6))
plt.subplot(144)
sns.histplot(data=df[df.Location=='New York'],x='Quantity',kde=True,hue='Consumption_Level')

plt.show()

# %%
## Multivariate analysis using pieplot

plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1,5,1)
size = df['Location'].value_counts()
labels = 'Chicago', 'Los Angeles','New York'
color = ['red','green','blue']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Location', fontsize = 20)
plt.axis('off')

plt.show()
